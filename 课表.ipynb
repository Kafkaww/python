# %%
import datetime

time = datetime.datetime.today().weekday()

week_time = int(time)


if week_time == 1:
    print('周一');print('1-2节python')
    
elif week_time == 2:
    print('周二');print('1-2节形势与政策');print('8-9节网络广告营销')
    
elif week_time == 3:
    print('周三');print('1-2节网络文案与创意写作')
    
elif week_time == 4:
    print('周四');print('8-10节线上调查与统计')
    
elif week_time == 5:
    print('周五');print('1-2节ai软件应用')
    
else:
    print('周末');print('睡大觉')
# Out:
# 周末
# 睡大觉
